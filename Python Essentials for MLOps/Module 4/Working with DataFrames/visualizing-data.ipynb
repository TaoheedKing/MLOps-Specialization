# %% [markdown]
# # Visualizing data
# `matplotlib` is able to produce meaningful data plots right in a notebook with little effort using Pandas DataFrames. This notebook covers a few of those capabilities.

# %%
# Load your dataframe
import pandas as pd
csv_url = "https://raw.githubusercontent.com/paiml/wine-ratings/main/wine-ratings.csv"
df = pd.read_csv(csv_url, index_col=0)
df.drop('grape', axis=1, inplace=True)
df = df.dropna()
df.head()
# Out:
#                                                 name                   region  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    Mendocino, California
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...               California
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...               California
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013  North Coast, California
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014               California
#
#     variety  rating                                              notes
# 0  Red Wine    91.0  This is a very special, limited release of 100...
# 1  Red Wine    89.0  The California Gold Rush was a period of coura...
# 2  Red Wine    90.0  The California Gold Rush was a period of coura...
# 3  Red Wine    91.0  The wine has a deep, rich purple color. An int...
# 4  Red Wine    90.0  Batch #004 is the first release of the 2014 vi...

# %%
ndf = pd.read_csv("us_births_2016_2021.csv", index_col=0)
ndf.head()
# Out:
#         State Abbreviation  Year Gender  \
# State
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
#
#                       Education Level of Mother  Education Level Code  \
# State
# Alabama                       8th grade or less                     1
# Alabama  9th through 12th grade with no diploma                     2
# Alabama   High school graduate or GED completed                     3
# Alabama   Some college credit, but not a degree                     4
# Alabama               Associate degree (AA, AS)                     5
#
#          Number of Births  Average Age of Mother (years)  \
# State
# Alabama              1052                           27.8
# Alabama              3436                           24.1
# Alabama              8777                           25.4
# ...

# %% [markdown]
# Import `matplotlib` and set the `inline` magic line

# %%
# !pip install matplotlib

# %%
df['rating'] = df['rating'].apply(lambda x: int(x))

# %%
ndf['Number of Births'] = ndf['Number of Births'].apply(lambda x: int(x))

# %%
df.plot()
# Out:
# <AxesSubplot: >

# %%
ndf.plot()
# Out:
# <AxesSubplot: xlabel='State'>

# %%
df["variety"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/taoheedking/Documents/ML Ops Specialization/Python Essentials for MLOps/Module 4/Working with DataFrames/visualizing-data.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/taoheedking/Documents/ML%20Ops%20Specialization/Python%20Essentials%20for%20MLOps/Module%204/Working%20with%20DataFrames/visualizing-data.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df["variety"].plot()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_core.py:972, in PlotAccessor.__call__(self, *args, **kwargs)
#     969             label_name = label_kw or data.columns
#     970             data.columns = label_name
# --> 972 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
df.plot.scatter(x="rating", y="variety", alpha=0.5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='rating', ylabel='variety'>

# %%
# number of births yoy in the US
ndf.plot.scatter(x="Year", y="Number of Births", alpha=0.5)
# Out:
# <AxesSubplot: xlabel='Year', ylabel='Number of Births'>
