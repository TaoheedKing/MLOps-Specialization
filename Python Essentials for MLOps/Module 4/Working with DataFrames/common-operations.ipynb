# %% [markdown]
# # Common Dataframe operations
# Selecting, or subset selections of data like columns and rows are very common when working with datasets that might have data that is not interesting or needs to be dropped.

# %%
# Load your dataframe
import pandas as pd
csv_url = "https://raw.githubusercontent.com/paiml/wine-ratings/main/wine-ratings.csv"
df = pd.read_csv(csv_url, index_col=0)
df.head()
# Out:
#                                                 name  grape  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    NaN
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    NaN
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    NaN
#
#                     region   variety  rating  \
# 0    Mendocino, California  Red Wine    91.0
# 1               California  Red Wine    89.0
# 2               California  Red Wine    90.0
# 3  North Coast, California  Red Wine    91.0
# 4               California  Red Wine    90.0
#
#                                                notes
# 0  This is a very special, limited release of 100...
# 1  The California Gold Rush was a period of coura...
# 2  The California Gold Rush was a period of coura...
# 3  The wine has a deep, rich purple color. An int...
# 4  Batch #004 is the first release of the 2014 vi...

# %%
# Load us_births_2016_2021.csv dataset
import pandas as pd
ndf = pd.read_csv("us_births_2016_2021.csv", index_col=0)
ndf.head(15)
# Out:
#         State Abbreviation  Year Gender  \
# State
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
#
#                                  Education Level of Mother  \
# State
# Alabama                                  8th grade or less
# Alabama             9th through 12th grade with no diploma
# Alabama              High school graduate or GED completed
# Alabama              Some college credit, but not a degree
# Alabama                          Associate degree (AA, AS)
# Alabama                     Bachelor's degree (BA, AB, BS)
# Alabama      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# Alabama  Doctorate (PhD, EdD) or Professional Degree (M...
# Alabama                              Unknown or Not Stated
# Alabama                                  8th grade or less
# Alabama             9th through 12th grade with no diploma
# Alabama              High school graduate or GED completed
# Alabama              Some college credit, but not a degree
# Alabama                          Associate degree (AA, AS)
# Alabama                     Bachelor's degree (BA, AB, BS)
#
#          Education Level Code  Number of Births  \
# State
# Alabama                     1              1052
# Alabama                     2              3436
# Alabama                     3              8777
# Alabama                     4              6453
# Alabama                     5              2227
# Alabama                     6              4453
# Alabama                     7              1910
# Alabama                     8               487
# Alabama                    -9                65
# Alabama                     1              1188
# Alabama                     2              3657
# Alabama                     3              9284
# Alabama                     4              6516
# Alabama                     5              2460
# Alabama                     6              4645
#
#          Average Age of Mother (years)  Average Birth Weight (g)
# State
# Alabama                           27.8                    3116.9
# Alabama                           24.1                    3040.0
# Alabama                           25.4                    3080.0
# Alabama                           26.7                    3121.9
# Alabama                           28.9                    3174.3
# Alabama                           30.3                    3239.0
# Alabama                           32.0                    3263.5
# Alabama                           33.1                    3196.7
# Alabama                           27.7                    3083.9
# Alabama                           27.6                    3232.9
# Alabama                           23.9                    3121.2
# Alabama                           25.2                    3197.9
# Alabama                           26.7                    3252.1
# Alabama                           29.0                    3301.4
# Alabama                           30.3                    3376.1

# %%
# i want to see waht all the columns are
ndf.columns

# i want to see more information about the dataframe
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5496 entries, Alabama to Wyoming
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State Abbreviation             5496 non-null   object
#  1   Year                           5496 non-null   int64
#  2   Gender                         5496 non-null   object
#  3   Education Level of Mother      5496 non-null   object
#  4   Education Level Code           5496 non-null   int64
#  5   Number of Births               5496 non-null   int64
#  6   Average Age of Mother (years)  5496 non-null   float64
#  7   Average Birth Weight (g)       5496 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 386.4+ KB

# %% [markdown]
# ## DataFrame columns

# %%
wine_notes = df["notes"]
wine_notes.head()
# Out:
# 0    This is a very special, limited release of 100...
# 1    The California Gold Rush was a period of coura...
# 2    The California Gold Rush was a period of coura...
# 3    The wine has a deep, rich purple color. An int...
# 4    Batch #004 is the first release of the 2014 vi...
# Name: notes, dtype: object

# %%
child_background = ndf["Education Level of Mother"]
child_background.head()
# Out:
# State
# Alabama                         8th grade or less
# Alabama    9th through 12th grade with no diploma
# Alabama     High school graduate or GED completed
# Alabama     Some college credit, but not a degree
# Alabama                 Associate degree (AA, AS)
# Name: Education Level of Mother, dtype: object

# %%
named_ratings = df[["name", "rating"]]
named_ratings.head()
# Out:
#                                                 name  rating
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    91.0
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    89.0
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    90.0
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    91.0
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    90.0

# %%
child_info = ndf[["State Abbreviation", "Gender", "Year"]]
child_info.head()
# Out:
#         State Abbreviation Gender  Year
# State
# Alabama                 AL      F  2016
# Alabama                 AL      F  2016
# Alabama                 AL      F  2016
# Alabama                 AL      F  2016
# Alabama                 AL      F  2016

# %% [markdown]
# ## Specific DataFrame rows

# %%
# filter rows based on a condition
top_named_ratings = named_ratings[df["rating"] > 96]
top_named_ratings.head()
# Out:
#                                                  name  rating
# 218                     Abreu Vineyards Cappella 2010    98.0
# 220              Abreu Vineyards Howell Mountain 2009    98.0
# 221  Abreu Vineyards Las Posadas Howell Mountain 2012    99.0
# 223                Abreu Vineyards Madrona Ranch 1996    98.0
# 227                Abreu Vineyards Madrona Ranch 2005    98.0

# %%
kids_born_during_pandemic = child_info[ndf["Year"] > 2019]
kids_born_during_pandemic.head()
# Out:
#         State Abbreviation Gender  Year
# State
# Alabama                 AL      F  2020
# Alabama                 AL      F  2020
# Alabama                 AL      F  2020
# Alabama                 AL      F  2020
# Alabama                 AL      F  2020

# %%
# the condition can be used on its own
df['rating'] > 96
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32775    False
# 32776    False
# 32777    False
# 32778    False
# 32779    False
# Name: rating, Length: 32780, dtype: bool

# %%
ndf['Year'] > 2019
# Out:
# State
# Alabama    False
# Alabama    False
# Alabama    False
# Alabama    False
# Alabama    False
#            ...
# Wyoming     True
# Wyoming     True
# Wyoming     True
# Wyoming     True
# Wyoming     True
# Name: Year, Length: 5496, dtype: bool

# %% [markdown]
# ## Using queries

# %%
df.query("rating > 93").head(10)
# Out:
#                             name  grape  \
# 8        12 Linajes Reserva 2012    NaN
# 36   3 Rings Reserve Shiraz 2004    NaN
# 109                   Aalto 2004    NaN
# 110                   Aalto 2005    NaN
# 111                   Aalto 2007    NaN
# 113                   Aalto 2008    NaN
# 115                   Aalto 2010    NaN
# 117                   Aalto 2012    NaN
# 121                   Aalto 2016    NaN
# 122                Aalto PS 2011    NaN
#
#                                                 region   variety  rating  \
# 8                              Ribera del Duero, Spain  Red Wine    94.0
# 36   Barossa Valley, Barossa, South Australia, Aust...  Red Wine    96.0
# 109                            Ribera del Duero, Spain  Red Wine    94.0
# 110                            Ribera del Duero, Spain  Red Wine    95.0
# 111                            Ribera del Duero, Spain  Red Wine    95.0
# 113                            Ribera del Duero, Spain  Red Wine    95.0
# 115                            Ribera del Duero, Spain  Red Wine    94.0
# 117                            Ribera del Duero, Spain  Red Wine    94.0
# 121                            Ribera del Duero, Spain  Red Wine    95.0
# 122                            Ribera del Duero, Spain  Red Wine    94.0
#
#                                                  notes
# 8    On the nose, a complex predominance of mineral...
# 36   Vintage Comments : Classic Barossa vintage con...
# 109  "The 2004 Aalto has a far different personalit...
# 110  The grapes come exclusively from old vineyards...
# 111  It is ironic that one of the youngest properti...
# 113  This wine's elegance and fruitful presence per...
# 115  This wine's elegance and fruitful presence per...
# 117                                                #6
# 121  Deep purple red color, as corresponds to old T...
# 122  AALTO PS, being made from a selection of our b...

# %%
ndf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5496 entries, Alabama to Wyoming
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State Abbreviation             5496 non-null   object
#  1   Year                           5496 non-null   int64
#  2   Gender                         5496 non-null   object
#  3   Education Level of Mother      5496 non-null   object
#  4   Education Level Code           5496 non-null   int64
#  5   Number of Births               5496 non-null   int64
#  6   Average Age of Mother (years)  5496 non-null   float64
#  7   Average Birth Weight (g)       5496 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 515.5+ KB

# %%
# in order to use a column name with spaces in it, you need to use backticks
ndf.query("`Average Age of Mother (years)`	< 30").head(20)
# Out:
#         State Abbreviation  Year Gender  \
# State
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2016      M
# Alabama                 AL  2017      F
# Alabama                 AL  2017      F
# Alabama                 AL  2017      F
# Alabama                 AL  2017      F
# Alabama                 AL  2017      F
# Alabama                 AL  2017      F
# Alabama                 AL  2017      M
# Alabama                 AL  2017      M
#
#                       Education Level of Mother  Education Level Code  \
# State
# Alabama                       8th grade or less                     1
# Alabama  9th through 12th grade with no diploma                     2
# Alabama   High school graduate or GED completed                     3
# Alabama   Some college credit, but not a degree                     4
# Alabama               Associate degree (AA, AS)                     5
# Alabama                   Unknown or Not Stated                    -9
# Alabama                       8th grade or less                     1
# Alabama  9th through 12th grade with no diploma                     2
# Alabama   High school graduate or GED completed                     3
# Alabama   Some college credit, but not a degree                     4
# Alabama               Associate degree (AA, AS)                     5
# Alabama                   Unknown or Not Stated                    -9
# Alabama                       8th grade or less                     1
# Alabama  9th through 12th grade with no diploma                     2
# Alabama   High school graduate or GED completed                     3
# Alabama   Some college credit, but not a degree                     4
# Alabama               Associate degree (AA, AS)                     5
# Alabama                   Unknown or Not Stated                    -9
# Alabama                       8th grade or less                     1
# Alabama  9th through 12th grade with no diploma                     2
#
#          Number of Births  Average Age of Mother (years)  \
# State
# Alabama              1052                           27.8
# Alabama              3436                           24.1
# Alabama              8777                           25.4
# Alabama              6453                           26.7
# Alabama              2227                           28.9
# Alabama                65                           27.7
# Alabama              1188                           27.6
# Alabama              3657                           23.9
# Alabama              9284                           25.2
# Alabama              6516                           26.7
# Alabama              2460                           29.0
# Alabama                56                           27.2
# Alabama              1012                           27.6
# Alabama              3283                           24.4
# Alabama              8962                           25.4
# Alabama              6384                           26.9
# Alabama              2411                           28.9
# Alabama                62                           28.0
# Alabama               978                           27.6
# Alabama              3345                           23.9
#
#          Average Birth Weight (g)
# State
# Alabama                    3116.9
# Alabama                    3040.0
# Alabama                    3080.0
# Alabama                    3121.9
# Alabama                    3174.3
# Alabama                    3083.9
# Alabama                    3232.9
# Alabama                    3121.2
# Alabama                    3197.9
# Alabama                    3252.1
# Alabama                    3301.4
# Alabama                    3107.7
# Alabama                    3139.6
# Alabama                    3040.6
# Alabama                    3068.8
# Alabama                    3112.3
# Alabama                    3197.2
# Alabama                    3014.4
# Alabama                    3229.8
# Alabama                    3116.2

# %%
# add more combined queries
df.query("rating > 94 & region == 'Ribera del Duero, Spain'").head(10)
# Out:
#                                                    name  grape  \
# 110                                          Aalto 2005    NaN
# 111                                          Aalto 2007    NaN
# 113                                          Aalto 2008    NaN
# 121                                          Aalto 2016    NaN
# 123                                       Aalto PS 2013    NaN
# 125                                       Aalto PS 2015    NaN
# 365   Adega Pena das Donas Ribeira Sacra Verdes Mata...    NaN
# 2058                            Antonino Izquierdo 2006    NaN
# 5781          Bodegas Uvaguilera Aguilera Palomero 2001    NaN
# 5804             Bodegas Valderiz Ribera del Duero 2016    NaN
#
#                        region   variety  rating  \
# 110   Ribera del Duero, Spain  Red Wine    95.0
# 111   Ribera del Duero, Spain  Red Wine    95.0
# 113   Ribera del Duero, Spain  Red Wine    95.0
# 121   Ribera del Duero, Spain  Red Wine    95.0
# 123   Ribera del Duero, Spain  Red Wine    95.0
# 125   Ribera del Duero, Spain  Red Wine    95.0
# 365   Ribera del Duero, Spain  Red Wine    95.0
# 2058  Ribera del Duero, Spain  Red Wine    95.0
# 5781  Ribera del Duero, Spain  Red Wine    96.0
# 5804  Ribera del Duero, Spain  Red Wine    96.0
#
#                                                   notes
# 110   The grapes come exclusively from old vineyards...
# 111   It is ironic that one of the youngest properti...
# 113   This wine's elegance and fruitful presence per...
# 121   Deep purple red color, as corresponds to old T...
# 123   Aalto PS (Pagos Seleccionada) is made only in ...
# 125   Aalto PS (Pagos Seleccionada) is made only in ...
# 365                                         100% Mencia
# 2058  Izquierdo displays an intense and clear red co...
# 5781  The nose presents a perfect balance between th...
# 5804  The grapes are sourced from vineyards planted ...

# %%
# whenever specifying a string in a query, you need to use single quotes
# MD is wrapped in single quotes because it is a string
ndf.query("`Average Age of Mother (years)`	< 30 & `State Abbreviation` == 'MD'").head(15)
# Out:
#          State Abbreviation  Year Gender  \
# State
# Maryland                 MD  2016      F
# Maryland                 MD  2016      F
# Maryland                 MD  2016      F
# Maryland                 MD  2016      F
# Maryland                 MD  2016      M
# Maryland                 MD  2016      M
# Maryland                 MD  2016      M
# Maryland                 MD  2016      M
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      M
# Maryland                 MD  2017      M
# Maryland                 MD  2017      M
#
#                        Education Level of Mother  Education Level Code  \
# State
# Maryland                       8th grade or less                     1
# Maryland  9th through 12th grade with no diploma                     2
# Maryland   High school graduate or GED completed                     3
# Maryland   Some college credit, but not a degree                     4
# Maryland                       8th grade or less                     1
# Maryland  9th through 12th grade with no diploma                     2
# Maryland   High school graduate or GED completed                     3
# Maryland   Some college credit, but not a degree                     4
# Maryland  9th through 12th grade with no diploma                     2
# Maryland   High school graduate or GED completed                     3
# Maryland   Some college credit, but not a degree                     4
# Maryland                   Unknown or Not Stated                    -9
# Maryland                       8th grade or less                     1
# Maryland  9th through 12th grade with no diploma                     2
# Maryland   High school graduate or GED completed                     3
#
#           Number of Births  Average Age of Mother (years)  \
# State
# Maryland              1527                           29.4
# Maryland              3057                           25.9
# Maryland              7191                           26.8
# Maryland              7001                           28.4
# Maryland              1586                           29.8
# Maryland              3162                           25.5
# Maryland              7466                           26.8
# Maryland              7411                           28.4
# Maryland              2886                           26.0
# Maryland              7137                           27.2
# Maryland              6766                           28.6
# Maryland               177                           29.7
# Maryland              1561                           29.5
# Maryland              2915                           26.1
# Maryland              7297                           26.9
#
#           Average Birth Weight (g)
# State
# Maryland                    3243.8
# Maryland                    3108.5
# Maryland                    3129.3
# Maryland                    3164.8
# Maryland                    3329.6
# Maryland                    3216.0
# Maryland                    3242.8
# Maryland                    3311.1
# Maryland                    3107.2
# Maryland                    3121.1
# Maryland                    3168.7
# Maryland                    3160.2
# Maryland                    3330.8
# Maryland                    3216.1
# Maryland                    3228.7

# %%
# chain queries to use the Python engine to operate on strings
top_wines = df.query("rating > 95")
# na=False is needed because we have some NaN region descriptions!
paso_robles = top_wines.query("region.str.contains('Robles', na=False)", engine='python')

# %%
# This query looks for female parents older than 30 
women_over_30 = ndf.query("`Average Age of Mother (years)`	> 30 & Gender == 'F'")

# show me a table of women in maryland over the age of 30
# md_women_over_30 = women_over_30.query("`State Abbreviation` == 'MD'")

# looking for women iver 30 in maryland
# the query looks for a string that contains MD
# na=False is needed to tell the program to ignore some NaN region in the data!
# the engine='python' is needed to tell the program to use the Python engine to operate on strings
md_women_over_30 = women_over_30.query("`State Abbreviation`.str.contains('MD', na=False)", engine='python')
md_women_over_30.head(15)
# Out:
#          State Abbreviation  Year Gender  \
# State
# Maryland                 MD  2016      F
# Maryland                 MD  2016      F
# Maryland                 MD  2016      F
# Maryland                 MD  2016      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2017      F
# Maryland                 MD  2018      F
# Maryland                 MD  2018      F
# Maryland                 MD  2018      F
# Maryland                 MD  2018      F
# Maryland                 MD  2018      F
# Maryland                 MD  2019      F
#
#                                   Education Level of Mother  \
# State
# Maryland                          Associate degree (AA, AS)
# Maryland                     Bachelor's degree (BA, AB, BS)
# Maryland      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# Maryland  Doctorate (PhD, EdD) or Professional Degree (M...
# Maryland                                  8th grade or less
# Maryland                          Associate degree (AA, AS)
# Maryland                     Bachelor's degree (BA, AB, BS)
# Maryland      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# Maryland  Doctorate (PhD, EdD) or Professional Degree (M...
# Maryland                                  8th grade or less
# Maryland                          Associate degree (AA, AS)
# Maryland                     Bachelor's degree (BA, AB, BS)
# Maryland      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# Maryland  Doctorate (PhD, EdD) or Professional Degree (M...
# Maryland                          Associate degree (AA, AS)
#
#           Education Level Code  Number of Births  \
# State
# Maryland                     5              2288
# Maryland                     6              7751
# Maryland                     7              5130
# Maryland                     8              1608
# Maryland                     1              1504
# Maryland                     5              2325
# Maryland                     6              7672
# Maryland                     7              5164
# Maryland                     8              1573
# Maryland                     1              1527
# Maryland                     5              2193
# Maryland                     6              7600
# Maryland                     7              5218
# Maryland                     8              1579
# Maryland                     5              2237
#
#           Average Age of Mother (years)  Average Birth Weight (g)
# State
# Maryland                           30.5                    3226.2
# Maryland                           31.6                    3260.2
# Maryland                           33.1                    3268.2
# Maryland                           34.4                    3266.8
# Maryland                           30.1                    3239.7
# Maryland                           30.6                    3221.4
# Maryland                           31.7                    3251.4
# Maryland                           33.3                    3255.5
# Maryland                           34.5                    3235.7
# Maryland                           30.1                    3242.4
# Maryland                           30.6                    3231.6
# Maryland                           31.8                    3258.4
# Maryland                           33.3                    3245.3
# Maryland                           34.7                    3229.2
# Maryland                           30.7                    3208.2
