# %% [markdown]
# # Applying Functions
# One of the key concepts in Pandas is that you can apply functions to the data frame itself. This differs from how data manipulation is done usually in Python, where loops and new data structures is primarily how you end up operating.

# %%
# Load your dataframe
import pandas as pd
csv_url = "https://raw.githubusercontent.com/paiml/wine-ratings/main/wine-ratings.csv"
df = pd.read_csv(csv_url, index_col=0)
df.head()
# Out:
#                                                 name  grape  \
# 0  1000 Stories Bourbon Barrel Aged Batch Blue Ca...    NaN
# 1  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 2  1000 Stories Bourbon Barrel Aged Gold Rush Red...    NaN
# 3    1000 Stories Bourbon Barrel Aged Zinfandel 2013    NaN
# 4    1000 Stories Bourbon Barrel Aged Zinfandel 2014    NaN
#
#                     region   variety  rating  \
# 0    Mendocino, California  Red Wine    91.0
# 1               California  Red Wine    89.0
# 2               California  Red Wine    90.0
# 3  North Coast, California  Red Wine    91.0
# 4               California  Red Wine    90.0
#
#                                                notes
# 0  This is a very special, limited release of 100...
# 1  The California Gold Rush was a period of coura...
# 2  The California Gold Rush was a period of coura...
# 3  The wine has a deep, rich purple color. An int...
# 4  Batch #004 is the first release of the 2014 vi...

# %%
ndf = pd.read_csv("us_births_2016_2021.csv", index_col=0)
ndf.head(10)
# Out:
#         State Abbreviation  Year Gender  \
# State
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      M
#
#                                  Education Level of Mother  \
# State
# Alabama                                  8th grade or less
# Alabama             9th through 12th grade with no diploma
# Alabama              High school graduate or GED completed
# Alabama              Some college credit, but not a degree
# Alabama                          Associate degree (AA, AS)
# Alabama                     Bachelor's degree (BA, AB, BS)
# Alabama      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# Alabama  Doctorate (PhD, EdD) or Professional Degree (M...
# Alabama                              Unknown or Not Stated
# Alabama                                  8th grade or less
#
#          Education Level Code  Number of Births  \
# State
# Alabama                     1              1052
# Alabama                     2              3436
# Alabama                     3              8777
# Alabama                     4              6453
# Alabama                     5              2227
# Alabama                     6              4453
# Alabama                     7              1910
# Alabama                     8               487
# Alabama                    -9                65
# Alabama                     1              1188
#
#          Average Age of Mother (years)  Average Birth Weight (g)
# State
# Alabama                           27.8                    3116.9
# Alabama                           24.1                    3040.0
# Alabama                           25.4                    3080.0
# Alabama                           26.7                    3121.9
# Alabama                           28.9                    3174.3
# Alabama                           30.3                    3239.0
# Alabama                           32.0                    3263.5
# Alabama                           33.1                    3196.7
# Alabama                           27.7                    3083.9
# Alabama                           27.6                    3232.9

# %% [markdown]
# We want to set the "top" wines given some arbitrary opinion on the rating. Wines are usually rated from 80 points to 100, and wines in the 90-94 point range are already good. So let's set the business requirement to set anything that is 95 points or greater to be "good".

# %%
# the function can be a regular function or a headless one with lambda

def good_wine(value):
    if value > 94:
        return True
    return False

df['good'] = df['rating'].apply(good_wine)
df.query('rating > 94').head()
# Out:
#                             name  grape  \
# 36   3 Rings Reserve Shiraz 2004    NaN
# 110                   Aalto 2005    NaN
# 111                   Aalto 2007    NaN
# 113                   Aalto 2008    NaN
# 121                   Aalto 2016    NaN
#
#                                                 region   variety  rating  \
# 36   Barossa Valley, Barossa, South Australia, Aust...  Red Wine    96.0
# 110                            Ribera del Duero, Spain  Red Wine    95.0
# 111                            Ribera del Duero, Spain  Red Wine    95.0
# 113                            Ribera del Duero, Spain  Red Wine    95.0
# 121                            Ribera del Duero, Spain  Red Wine    95.0
#
#                                                  notes  good
# 36   Vintage Comments : Classic Barossa vintage con...  True
# 110  The grapes come exclusively from old vineyards...  True
# 111  It is ironic that one of the youngest properti...  True
# 113  This wine's elegance and fruitful presence per...  True
# 121  Deep purple red color, as corresponds to old T...  True

# %%
# this function will dictate whether the average age of mother are in the danger zone or not, and return a boolean
def danger_zone(value):
    if (value) > 30:
        return True
    return False

ndf['in_danger'] = ndf['Average Age of Mother (years)'].apply(danger_zone)
ndf.head(10)
# Out:
#         State Abbreviation  Year Gender  \
# State
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      F
# Alabama                 AL  2016      M
#
#                                  Education Level of Mother  \
# State
# Alabama                                  8th grade or less
# Alabama             9th through 12th grade with no diploma
# Alabama              High school graduate or GED completed
# Alabama              Some college credit, but not a degree
# Alabama                          Associate degree (AA, AS)
# Alabama                     Bachelor's degree (BA, AB, BS)
# Alabama      Master's degree (MA, MS, MEng, MEd, MSW, MBA)
# Alabama  Doctorate (PhD, EdD) or Professional Degree (M...
# Alabama                              Unknown or Not Stated
# Alabama                                  8th grade or less
#
#          Education Level Code  Number of Births  \
# State
# Alabama                     1              1052
# Alabama                     2              3436
# Alabama                     3              8777
# Alabama                     4              6453
# Alabama                     5              2227
# Alabama                     6              4453
# Alabama                     7              1910
# Alabama                     8               487
# Alabama                    -9                65
# Alabama                     1              1188
#
#          Average Age of Mother (years)  Average Birth Weight (g)  in_danger
# State
# Alabama                           27.8                    3116.9      False
# Alabama                           24.1                    3040.0      False
# Alabama                           25.4                    3080.0      False
# Alabama                           26.7                    3121.9      False
# Alabama                           28.9                    3174.3      False
# Alabama                           30.3                    3239.0       True
# Alabama                           32.0                    3263.5       True
# Alabama                           33.1                    3196.7       True
# Alabama                           27.7                    3083.9      False
# Alabama                           27.6                    3232.9      False
